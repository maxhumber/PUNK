# %%
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# All transactions until May 16, 2021:

# %%
tdf = pd.read_csv("data/transactions.csv")
tdf["date"] = pd.to_datetime(tdf["date"])

# %%
tdf.shape
# Out:
# (115966, 7)

# %%
tdf.head()
# Out:
#         date  id     type      from        to   eth    usd
# 0 2017-06-23   0     Sold  0xc352b5  0x00d7c9  0.98  320.0
# 1 2017-06-23   0      Bid  0x00d7c9       NaN  0.98  320.0
# 2 2017-06-23   0      Bid  0x948a10       NaN  0.67  219.0
# 3 2017-06-23   0  Claimed       NaN  0xc352b5   NaN    NaN
# 4 2017-06-23   1  Claimed       NaN  0xc352b5   NaN    NaN

# %% [markdown]
# Zoom in on one:

# %%
punk = 6601
pdf = tdf[tdf["id"] == punk]

# %%
pdf
# Out:
#             date    id             type       from         to    eth      usd
# 6674  2017-06-23  6601          Claimed        NaN   0x0b30fd    NaN      NaN
# 12130 2017-06-26  6601              Bid   0x717403        NaN   0.05     13.0
# 13181 2017-06-28  6601    Bid Withdrawn   0x717403        NaN   0.05     16.0
# 15803 2017-07-06  6601          Offered        NaN        NaN   0.52    138.0
# 16555 2017-07-10  6601             Sold   0x0b30fd   0x727ca3   0.52    107.0
# 59045 2020-12-17  6601              Bid   0xc7c6b9        NaN   0.00      0.0
# 72697 2021-02-17  6601          Offered        NaN        NaN  15.00  27684.0
# 73621 2021-02-18  6601             Sold   0x727ca3   0xca1585  15.00  28533.0
# 76076 2021-02-21  6601          Offered        NaN        NaN  25.00  49189.0
# 77134 2021-02-22  6601          Offered        NaN        NaN  35.00  67088.0
# 77835 2021-02-23  6601  Offer Withdrawn        NaN        NaN    NaN      NaN
# 84446 2021-03-08  6601              Bid   0xe3bf86        NaN  17.00  29489.0
# 84447 2021-03-08  6601          Offered        NaN        NaN  24.00  40341.0
# 84803 2021-03-09  6601    Bid Withdrawn   0xe3bf86        NaN  17.00  31122.0
# 86397 2021-03-12  6601          Offered        NaN        NaN  37.49  67790.0
# 86398 2021-03-12  6601             Sold   0xca1585    Pranksy  24.00  43397.0
# 94980 2021-03-30  6601           (Wrap)   0x776758  WrappedC…    NaN      NaN
# 94981 2021-03-30  6601         Transfer    Pranksy   0x776758    NaN      NaN
# 97117 2021-04-07  6601          Offered        NaN        NaN  17.60  34645.0
# 97118 2021-04-07  6601         (Unwrap)  WrappedC…   0x67edd0    NaN      NaN
# 97119 2021-04-07  6601             Sold    Pranksy   0x67edd0  14.80  29133.0
# 97709 2021-04-08  6601          Offered        NaN        NaN  22.50  46076.0
# 97710 2021-04-08  6601          Offered        NaN        NaN  23.60  48329.0
# 97711 2021-04-08  6601          Offered        NaN        NaN  31.00  63980.0
# 97712 2021-04-08  6601          Offered        NaN        NaN  25.00  51676.0
# 98507 2021-04-09  6601              Bid   0xf3fd33        NaN  18.00  37330.0
# 99092 2021-04-10  6601    Bid Withdrawn      Gmugr        NaN  19.00  40966.0
# 99093 2021-04-10  6601              Bid      Gmugr        NaN  19.00  41059.0
# 99094 2021-04-10  6601          Offered        NaN        NaN  21.00  45381.0
# 99095 2021-04-10  6601          Offered        NaN        NaN  22.00  47725.0
# 99547 2021-04-11  6601             Sold   0x67edd0   0xf3fd33  20.80  44653.0
# 99548 2021-04-11  6601    Bid Withdrawn   0xf3fd33        NaN  19.00  40788.0
# 99549 2021-04-11  6601              Bid   0xf3fd33        NaN  19.00  40661.0
# 99550 2021-04-11  6601          Offered        NaN        NaN  20.80  44480.0

# %%
pdf = pdf.dropna(subset=["eth"])

# %%
alt.Chart(pdf).encode(x="date", y="eth", color="type").mark_circle()
# Out:
# alt.Chart(...)

# %%
pdf = pdf[pdf["date"] >= "2021-01-01"]

# %%
(
    alt.Chart(pdf)
    .encode(x="date", y="eth", color="type")
    .mark_circle()
    .properties(title='Punk 6601')
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Quick look general trend:

# %%
sold = tdf[tdf["type"] == "Sold"].sample(5000)

# %%
alt.Chart(sold).encode(x="date", y="usd").mark_circle()
# Out:
# alt.Chart(...)

# %%
sold["eth_log"] = np.log(sold["eth"])
# Out:
# /Users/max/opt/miniconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
alt.Chart(sold).encode(x="date", y="eth_log").mark_circle()
# Out:
# alt.Chart(...)

# %% [markdown]
# Crude analysis based on attributes:

# %%
adf = pd.read_csv("data/attributes.csv")

# %%
sold90 = sold[(pd.Timestamp("now") - sold["date"]).dt.days <= 90]
sold90 = sold90[["id", "eth", "date"]]
df = pd.merge(sold90, adf, on="id")
df = df.dropna()

# %%
df
# Out:
#         id    eth       date  \
# 0     9324  23.29 2021-05-03
# 1     9324  23.00 2021-05-03
# 2     5177  30.00 2021-03-12
# 3     3958  26.60 2021-03-17
# 4     1495  34.00 2021-05-01
# ...    ...    ...        ...
# 1301  9815  23.30 2021-05-03
# 1302  2223  34.99 2021-03-13
# 1303  4325  16.00 2021-04-08
# 1304  6287  26.99 2021-03-20
# 1305  5894  21.94 2021-03-17
#
#                                              attributes
# 0     Female + Black Lipstick + Clown Eyes Green + E...
# 1     Female + Black Lipstick + Clown Eyes Green + E...
# 2     Female + Clown Eyes Green + Straight Hair Blon...
# 3          Male + Cigarette + Headband + Regular Shades
# 4                     Female + Hot Lipstick + Dark Hair
# ...                                                 ...
# 1301  Male + Muttonchops + Clown Eyes Green + Mohawk...
# 1302             Male + Police Cap + Horned Rim Glasses
# 1303           Male + Classic Shades + Earring + Do-rag
# 1304                     Male + Fedora + Classic Shades
# 1305      Male + Clown Eyes Blue + Peak Spike + Earring
#
# [1303 rows x 4 columns]

# %%
df['attributes'] = df['attributes'].apply(lambda x: x.split(' + '))
ethattr = df.explode('attributes')
ethattr
# Out:
#         id    eth       date          attributes
# 0     9324  23.29 2021-05-03              Female
# 0     9324  23.29 2021-05-03      Black Lipstick
# 0     9324  23.29 2021-05-03    Clown Eyes Green
# 0     9324  23.29 2021-05-03             Earring
# 0     9324  23.29 2021-05-03  Straight Hair Dark
# ...    ...    ...        ...                 ...
# 1304  6287  26.99 2021-03-20      Classic Shades
# 1305  5894  21.94 2021-03-17                Male
# 1305  5894  21.94 2021-03-17     Clown Eyes Blue
# 1305  5894  21.94 2021-03-17          Peak Spike
# 1305  5894  21.94 2021-03-17             Earring
#
# [4930 rows x 4 columns]

# %%
ethattr = ethattr.groupby("attributes")["eth"].median().reset_index()

# %%
alt.Chart(ethattr).encode(x="eth", y="attributes").mark_bar()
# Out:
# alt.Chart(...)
